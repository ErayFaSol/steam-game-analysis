# %%
import os
import pandas as pd

# Obtener el directorio de trabajo actual (donde está el notebook)
current_dir = os.getcwd()

# Subir un nivel para llegar a la raíz del proyecto
root_dir = os.path.dirname(current_dir)

# Construir la ruta completa al archivo JSON desde la raíz del proyecto
data_path = os.path.join(root_dir, 'data/raw/steamgames.json')

# Cargar el dataset desde la ruta especificada
df = pd.read_json(data_path)

# Visualizar las primeras filas del dataset
df.head()
# Out:
#                            name  discount  orig_price  disc_price  \
# 0                 Lucius Demake        85         499          74
# 1                 Titan Station        35        1479         961
# 2  Restaurant Manager Simulator        90        4399         439
# 3            Please, Forgive Me        34         689         454
# 4               DeepStates [VR]        70         999         299
#
#                                                 tags  \
# 0  [\r\n\t\t\t\t\t\t\t\t\t\t\t\tAdventure\t\t\t\t...
# 1  [\r\n\t\t\t\t\t\t\t\t\t\t\t\tWalking Simulator...
# 2  [\r\n\t\t\t\t\t\t\t\t\t\t\t\tStrategy\t\t\t\t\...
# 3  [\r\n\t\t\t\t\t\t\t\t\t\t\t\tHorror\t\t\t\t\t\...
# 4  [\r\n\t\t\t\t\t\t\t\t\t\t\t\tAtmospheric\t\t\t...
#
#                                              reviews  \
# 0  [\r\n\t\t\t\t\t\t\t\t\t\t\t\t- 81% of the 11 u...
# 1  [\r\n\t\t\t\t\t\t\t\t\t\t\t\t- 100% of the 12 ...
# 2  [\r\n\t\t\t\t\t\t\t\t\t\t\t\t- 91% of the 12 u...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2728 entries, 0 to 2727
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        2728 non-null   object
#  1   discount    2728 non-null   int64
#  2   orig_price  2728 non-null   int64
#  3   disc_price  2728 non-null   int64
#  4   tags        2728 non-null   object
#  5   reviews     2728 non-null   object
#  6   link        2728 non-null   object
# dtypes: int64(3), object(4)
# memory usage: 149.3+ KB
